# %% [markdown]
# ## HW3 - Levenberg-Marquardt Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ImageBlock import ImageBlock
from BlockSimulation import *
from scipy import linalg as la
import sys

# Set print options to suppress scientific notation
np.set_printoptions(suppress=True)

# %%
# define random seed
np.random.seed(0)

a = SimulateBlock(50, (36, 24), overlap=0.6 , num_images=5, num_strips=5, tie_pattern='3 mid frame', control_pattern='random first image',num_control_points=5, rotations_sigma=10, altitude=1000)

block = a.simulate_block()

SimulateBlock.add_noise_to_block(block, sigma_location=5, sigma_rotation=5*3600, sigma_image_points=1, sigma_tie_points=10)

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
fig.suptitle('Simulation of a block', fontsize=20)
block.draw_block(ax = axes)
axes.set_title(f'tie pattern: {a.tie_pattern}, control pattern: {a.control_pattern}, overlap: {a.overlap}', fontsize=15)
axes.set_xlabel('x [m]', fontsize=15)
axes.set_ylabel('y [m]', fontsize=15)
plt.show()
# fig.savefig('Simulated block with noise.png')

# %%
X,RMSE, sigmaX, condition_numbers=block.LevenbergMarquardt(0.01, 100, method='naive')
# X,RMSE, sigmaX, condition_numbers=block.BundleAdjustment(0.01, 100, method='naive')
# Out:
# c:\Users\lauterman\OneDrive - Technion\טכניון\תואר שני\קורסים\היבטים נומרים בפתרון תצלומים\code\Photogrammetry\Numerical_Aspects_in_Photogrammetry\ImageBlock.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   condition_numbers = condition_numbers.append({'A': cond_A, 'N': cond_N}, ignore_index=True)
# c:\Users\lauterman\OneDrive - Technion\טכניון\תואר שני\קורסים\היבטים נומרים בפתרון תצלומים\code\Photogrammetry\Numerical_Aspects_in_Photogrammetry\ImageBlock.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   condition_numbers = condition_numbers.append({'A': cond_A, 'N': cond_N}, ignore_index=True)
# iteration:  1
#  condition number A:  1.034913233562917e+16
#  condition number N:  1.0556262168683086e+16
#
# RMSE:  5.17744698983795 norm(dx):  0.6694172054366646
#
# iteration:  2
#  condition number A:  1.0347295509491058e+16
#  condition number N:  1.055427285780226e+16
#
# RMSE:  0.4695800499936974 norm(dx):  0.05637126381626689
# c:\Users\lauterman\OneDrive - Technion\טכניון\תואר שני\קורסים\היבטים נומרים בפתרון תצלומים\code\Photogrammetry\Numerical_Aspects_in_Photogrammetry\ImageBlock.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   condition_numbers = condition_numbers.append({'A': cond_A, 'N': cond_N}, ignore_index=True)
# c:\Users\lauterman\OneDrive - Technion\טכניון\תואר שני\קורסים\היבטים נומרים בפתרון תצלומים\code\Photogrammetry\Numerical_Aspects_in_Photogrammetry\ImageBlock.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   condition_numbers = condition_numbers.append({'A': cond_A, 'N': cond_N}, ignore_index=True)
# c:\Users\lauterman\OneDrive - Technion\טכניון\תואר שני\קורסים\היבטים נומרים בפתרון תצלומים\code\Photogrammetry\Numerical_Aspects_in_Photogrammetry\ImageBlock.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   condition_numbers = condition_numbers.append({'A': cond_A, 'N': cond_N}, ignore_index=True)
# iteration:  3
#  condition number A:  1.0347281874002044e+16
#  condition number N:  1.0554247349281568e+16
#
# RMSE:  0.06187746697348094 norm(dx):  0.013346139299861979
#
# iteration:  4
#  condition number A:  1.0347281874002044e+16
#  condition number N:  1.0554247349281568e+16
#
# RMSE:  0.06187746697348094 norm(dx):  0.013346139299861979
#
# iteration:  5
#  condition number A:  1.0347281874002044e+16
#  condition number N:  1.0554247349281568e+16
#
# RMSE:  0.06187746697348094 norm(dx):  0.013346139299861979
#
# iteration:  6
#  condition number A:  1.0347280257312024e+16
#  condition number N:  1.0554247958000258e+16
#
# RMSE:  0.061639379293298206 norm(dx):  0.009999053549540228
# c:\Users\lauterman\OneDrive - Technion\טכניון\תואר שני\קורסים\היבטים נומרים בפתרון תצלומים\code\Photogrammetry\Numerical_Aspects_in_Photogrammetry\ImageBlock.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   condition_numbers = condition_numbers.append({'A': cond_A, 'N': cond_N}, ignore_index=True)

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
fig.suptitle('Simulation of a block', fontsize=20)
block.draw_block(ax = axes)
axes.set_title(f'tie pattern: {a.tie_pattern}, control pattern: {a.control_pattern}, overlap: {a.overlap}', fontsize=15)
axes.set_xlabel('x [m]', fontsize=15)
axes.set_ylabel('y [m]', fontsize=15)
plt.show()
# fig.savefig('Simulation of a block.png')
